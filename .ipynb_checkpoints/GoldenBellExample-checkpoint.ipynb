# %%
import pandas as pd

# %%
df= pd.read_csv("goldenbell.csv",encoding='cp949')

# %%
check_list=[2, 6, 9, 12, 19, 20, 21, 23, 25, 26,
            28, 33, 35, 38, 45, 49, 55, 58, 61, 62,
           63, 65, 67, 70, 72, 75, 76, 77, 78, 82, 85, 87,
           94,101, 102, 103, 104, 105, 106, 110, 113,115, 118, 122, 123, 127, 128, 129, 130, 131,
           133, 135, 139, 140, 141, 142, 145, 148, 150, 151, 152, 153, 154, 155, 156 ,157, 158, 159, 160, 
           161, 162, 163, 164, 165, 166, 167, 168, 169, 170 ,171 ,172 ,173, 174, 175, 176, 177, 178, 179,
           180, 181, 182, 183, 184, 185, 186, 187 ,188 ,189 ,190 ,191 ,192, 193 ,194 ,195, 196 ,197, 198, 199]

# %%
for i in check_list:
    print("{}번) {}".format(i, df['문제'][i-1]))
    answer = input("입력 >> ")
    if answer == df['답'][i-1]:
        print("정답입니다.\n\n")
    else:
        print("오답입니다. 정답은 {} 입니다.\n\n".format(df['답'][i-1]))
# Out:
# 2번) 개방,  참여,  공유의  정신을  바탕으로  사용자가  직접  정보를  생산하여  쌍방향으로  소통하는  웹  기술은  무엇인가?
# 입력 >>
# 오답입니다. 정답은 웹2.0 입니다.
#
#
# 6번) 영향력을  주는  사람을  뜻하는  단어로,  최근에는  유투브,  페이스북,  인스타그램  등  소셜네트워크에서  많은  사람에게  영향
# 력을  미치는  사람을  나타낸다.  BTS와  같은  Kpop스타뿐  아니라  대도서관이나  이사배와  같은  유튜버들도  해당된다.  이들
# 을  뜻하는  단어는?
# 입력 >>
# 오답입니다. 정답은 인플루언서 입니다.
#
#
# 9번) 컴퓨터,  스마트폰  등을  이용해  인터넷  상에서  상품과  서비스를  교환하는  거래행위를  지칭하는  용어는?
# 입력 >>
# 오답입니다. 정답은 전자상거래(e-commerce) 입니다.
#
#
# 12번) 다수의  개체들이  서로  협력·경쟁을  통하여  얻게  된  지식  축적의  결과로  얻어진  집단적  능력을  일컫는  말로,  집단지능,  협
# 업지성,  공생적지능이라고도  하는  한다.  대표적인  사례로  위키피디아,  네이버  지식인  등이  있다.  무엇인가?
# 입력 >>
# 오답입니다. 정답은 집단지성 입니다.
#
#
# 19번) 비슷한  관심사를  가진  사람들이  이벤트  일정을  잡을  수  있도록  도와주는  웹사이트로,  모임을  조직하려는  사람과  비슷한
# 생각을  가진  사람들끼리  시간과  장소를  정해  만난  후  모임을  지속할  수  있도록  온라인과  오프라인을  연결해주는  서비스
# 라고  볼  수  있다.  무엇인가?
# 입력 >>
# 오답입니다. 정답은 밋업 입니다.
#
#
# 20번) 항상  원격으로  일하고  여행하는  사람을  말하며,  이들은  첨단  디지털  장비를  구비하고  여기저기  돌아다니면서  장소에  구
# 애받지  않고  일한다.  정보기술의  발달로  등장한  21세기형  신인류를  뜻하는  용어는?
# 입력 >>
# 오답입니다. 정답은 디지털  노마드 입니다.
#
#
# 21번) 인터넷을  통해  방송  프로그램·영화·교육  등  각종  미디어  콘텐츠를  제공하는  서비스로서,  넷플릭스,  왓챠플레이,  옥수수가
# 대표적이다.  이  서비스는  무엇인가?
# 입력 >>
# 오답입니다. 정답은 OTT서비스(온라인  유료  동영상  서비스) 입니다.
#
#
# 23번) 시간과  장소에  얽매이지  않고  언제  어디서나  일할  수  있는  체제를  일컫는  말로,  유연근문제,  모바일오피스,  재택근무,  원
# 격회의  및  원격협업  등의  근무형태가  있다.  무엇인가?
# 입력 >>
# 오답입니다. 정답은 스마트워크 입니다.
#
#
# 25번) 대용량의   데이터  속에서  지금까지  알지  못했던  규칙이나  패턴들을  찾아내어  새로운  가치를  추출하는  것을  의미하는  IT
# 용어는?
# 입력 >>
# 오답입니다. 정답은 빅데이터 입니다.
#
#
# 26번) 1995년  이후에  태어나  2000년  초반  IT붐과  함께  유년  시절부터  디지털  환경에  노출에  세대로서,  이들은  신기술에  민감
# 할  뿐아니라  소비활동에도  적극활용한다.  스마트폰과  함께  자라난  세대로  디지털  디바이스는  이들에게  가장  친한  친구
# 이다.  Z세대라고도  불리우는  이들은  누구인가?
# 입력 >>
# 오답입니다. 정답은 디지털네이티브(디지털원주민) 입니다.
#
#
# 28번) 음성이나  문자를  통한  인간과의  대화를  통해서  특정한  작업을  수행하도록  제작된  컴퓨터  프로그램으로,  이것은  쇼핑몰
# 에서  물건을  구입하거나  호텔에  예약을  하는  등  사람이  하는  업무를  대신할  수도  있다.  무엇인가?
# 입력 >>
# 오답입니다. 정답은 챗봇 입니다.
#
#
# 33번) 평면  디스플레이나  프로젝터  등에  의해  영상이나  정보를  표시하는  광고  매체로서  백화점이나  지하철  역사  안에서  흔히 보이는  광고  영상  디스플레이들입니다.  이를  무엇이라고  할까요?
# 입력 >>
# 오답입니다. 정답은 디지털  사이니지 입니다.
#
#
# 35번) 지혜의  인간을  호모사피엔스,  놀이를  즐기는  인간을  호모루덴스라고  한다.  디지털  기기를  사용하는  인간을  호모  디지쿠
# 스라고  한다.  그러면  휴대전화를  하는  인간으로  스마트폰을  생활화한  인류를  무엇이라고  할까?
# 입력 >>
# 오답입니다. 정답은 호모  모빌리티쿠스 입니다.
#
#
# 38번) 금융(Financial)과  기술(Technique)의  합성어?
# 입력 >>
# 오답입니다. 정답은 핀테크(FinTech) 입니다.
#
#
# 45번) 인간이  가지고  있는  유전체의  모든  염기서열을  해석하기  위한  프로젝트?
# 입력 >>
# 오답입니다. 정답은 (인간)  게놈  프로젝트 입니다.
#
#
# 49번) (                 )시스템은  우리  대학의  학생들이  스마트한  캠퍼스  생활을  즐길  수  있도록  구축되었다.  모바일  ID를  통해  강의
# 출결이  가능할뿐만  아니라  도서관  이용,  학생  생활관  출입,  교내  편의시설을  쉽게  이용할  수  있다.
# 입력 >>
# 오답입니다. 정답은 (한림대학교)  스마트  모빌리티 입니다.
#
#
# 55번) 다중접속  역할  수행  게임은  한명  이상의  플레이어가  인터넷을  통해  모두  같은  가상  공간에서  즐길  수  있는  롤플레잉  게
# 임(RPG)의  일종이다.
# 입력 >>
# 오답입니다. 정답은 MMORPG 입니다.
#
#
# 58번) 인터넷상에  저장  공간을  확보하여  이용하는  서비스를  일컷는말은?
# 입력 >>
# 오답입니다. 정답은 웹하드  ,웹드라이브 입니다.
#
#
# 61번) 모든  컴퓨터를  하나의  통신망  안에  연결하고자  하는  의도에서  만들어진  이름으로  컴퓨터를  연결하여  TCP/IP  통신프로
# 토콜을  이용해  정보를  주고받는  네트워크를  일컷는  말을  무엇이라고  하는가
# 입력 >>
# 오답입니다. 정답은 인터넷 입니다.
#
#
# 62번) 어떠한  문제를  해결하기  위해  정해진  일련의  절차나  방법을  공식화한  형태로  표현한  것을  무엇이라고  하는가
# 입력 >>
# 오답입니다. 정답은 알고리즘 입니다.
#
#
# 63번) 컴퓨터에서  연산및  제어를  처리하는  장치는?
# 입력 >>
# 오답입니다. 정답은 중앙처리장치  ,  CPU 입니다.
#
#
# 65번) windows와  같이  컴퓨터를  동작할  수  있게  해주는  (소프트웨어)프로그램을  무엇이라고  하는가?
# 입력 >>
# 오답입니다. 정답은 운영체제  ,   OS   ,Operating  System 입니다.
#
#
# 67번) 스티브  잡스가  설립한  컴퓨터  회사로  최초의  GUI  기반의  운영체제를  설치해  개인용  PC  판매한  회사는?
# 입력 >>
# 오답입니다. 정답은 애플 입니다.
#
#
# 70번) 인터넷에서  연결된  사용자들이  서로의  정보를  공유할  수  있는  공간
# 입력 >>
# 오답입니다. 정답은 월드와이드웹  ,  웹  ,www 입니다.
#
#
# 72번) 스스로를  복제하여  컴퓨터를  감염시키는  컴퓨터  프로그램을  무엇이라고  하는가
# 입력 >>
# 오답입니다. 정답은 바이러스 입니다.
#
#
# 75번) 특별한  지식을  소유한  사람들을  제외하고는  누구든지  읽어볼  수  없도록  알고리즘을  이용하여  정보(평문을  가리킴)를  전
# 달하는  과정이다.
# 입력 >>
# 오답입니다. 정답은 암호화 입니다.
#
#
# 76번) 전자적  증거물  등을  사법기관에  제출하기  위해  데이터를  수집,  분석,  보고서를  작성하는  일련의  작업을  말한다.
# 입력 >>
# 오답입니다. 정답은 컴퓨터포렌식  ,  디지털포렌식 입니다.
#
#
# 77번) 클라이언트에게  네트워크를  통해  정보나  서비스를  제공하는  컴퓨터(server  computer)  또는  프로그램(server  program)을
# 말한다
# 입력 >>
# 오답입니다. 정답은 서버 입니다.
#
#
# 78번) 역사상  최초의  프로그래머로  알려진  사람은
# 입력 >>
# 오답입니다. 정답은 에이다  러브레이스  ,  에이다 입니다.
#
#
# 82번) 컴퓨터(사람이나  기계)가  효과적으로  수행할  수  있도록  문제를  정의하고  그에  대한  답을  기술하는  것이  포함된  사고  과
# 정  일체를  일컫는다
# 입력 >>
# 오답입니다. 정답은 컴퓨팅사고 입니다.
#
#
# 85번) 통상적으로  사용되는  데이터  수집,  관리  및  처리  소프트웨어의  수용  한계를  넘어서는  크기의  데이터를  말한다
# 입력 >>
# 오답입니다. 정답은 빅데이터 입니다.
#
#
# 87번) 3차원  영상으로  된  입체  사진으로,  홀로그래피의  원리를  이용하여  만들어진다.  즉,  입체상을  재현하는  간섭  줄무늬를  기
# 록한  매체이다.
# 입력 >>
# 오답입니다. 정답은 홀로그램 입니다.
#
#
# 94번) 저장장치에  저장된  특정한  목적의  하나  또는  다수의  컴퓨터  프로그램을  (                         )  이라고  한다.
# 입력 >>
# 오답입니다. 정답은 소프트웨어 입니다.
#
#
# 101번) 컴퓨터의  기억을  담당하는  하드웨어의  이름은?
# 입력 >>
# 오답입니다. 정답은 memory  또는  메모리 입니다.
#
#
# 102번) 플래시  메모리,  하드디스크,  디스켓,  USB  메모리  등으로  분류되는  장치의  이름은?
# 입력 >>
# 오답입니다. 정답은 보조기억  장치 입니다.
#
#
# 103번) 2의보수에서  N비트  signed  정수  표현  범위는  -128  ~  127이다.  이때   N의  값은?
# 입력 >>
# 오답입니다. 정답은 8 입니다.
#
#
# 104번) 16진수를  뜻하는  3글자의  약어?
# 입력 >>
# 오답입니다. 정답은 HEX 입니다.
#
#
# 105번) 통신을  위해  컴퓨터  또는  단말들을  서로  연결하여  만든  망을  무엇이라고  하는가?
# 입력 >>
# 오답입니다. 정답은 네트워크 입니다.
#
#
# 106번) 이  문장은  Loop  문에서  만나면  돌던  Loop를  멈추고  나간다.  이  명령어는?
# 입력 >>
# 오답입니다. 정답은 continue 입니다.
#
#
# 110번) 정보  표현의  최소  단위는?
# 입력 >>
# 오답입니다. 정답은 bit  또는  비트 입니다.
#
#
# 113번) HTML  웹  표준으로  문서를  작성하여  HTTP를  통해  송수신  호스트  간에  전송하는  기술?
# 입력 >>
# 오답입니다. 정답은 월드  와이드  웹  또는  WWW 입니다.
#
#
# 115번) 컴퓨터의  두뇌라고  하는  하드웨어의  이름은?
# 입력 >>
# 오답입니다. 정답은 CPU 입니다.
#
#
# 118번) 주변장치  중  화면의  특정  위치를  지정하거나  선택하기  위해  사용하는  입력장치는?
# 입력 >>
# 오답입니다. 정답은 마우스 입니다.
#
#
# 122번) 시스템의  하드웨어  및  응용  소프트를  관리하고  실행하기  위한  플랫폼  및  서비스를  제공하는  시스템  소프트웨어를  뭐라
# 고  하는가?
# 입력 >>
# 오답입니다. 정답은 OS  또는  운영체제 입니다.
#
#
# 123번) 프로그램  내에서  오류를  찾아내  제거하는  작업을  뭐라고  부르는가?
# 입력 >>
# 오답입니다. 정답은 디버깅 입니다.
#
#
# 127번) 소프트웨어를  무단으로  수정하여  악용하거나,  정보를  훔쳐서  피해를  주는  행위를  무엇이라고  하는가?
# 입력 >>
# 오답입니다. 정답은 크래킹 입니다.
#
#
# 128번) 운영체제  중  가장  기본적인  컴퓨터의  입출력을  처리하는  소프트웨어  시스템은?
# 입력 >>
# 오답입니다. 정답은 bios  또는  바이오스 입니다.
#
#
# 129번) 실제로  존재하는  환경에  가상의  사물이나  정보를  합성하여  보여주는  컴퓨터  그래픽  기술?
# 입력 >>
# 오답입니다. 정답은 증강현실  또는  AR 입니다.
#
#
# 130번) 컴퓨터  네트워크에서  장치들이  서로를  인식하고  통신을  하기  위해  사용하는  특수한  번호?
# 입력 >>
# 오답입니다. 정답은 IP  주소 입니다.
#
#
# 131번) 여러  종류의  매체를  합쳐  여러  형식의  정보  콘텐츠와  정보처리를  사용하여  정보와  즐거움을  주는  것?
# 입력 >>
# 오답입니다. 정답은 멀티미디어 입니다.
#
#
# 133번) 산술  논리  장치의  영어  약어  표현은?
# 입력 >>
# 오답입니다. 정답은 ALU 입니다.
#
#
# 135번) 서로  다른  기종의  컴퓨터끼리  데이터를  송수신하기  위해  전송  형식이나  절차  등을  정한  통신  규약?
# 입력 >>
# 오답입니다. 정답은 프로토콜 입니다.
#
#
# 139번) 기억  장치  중  가장  속도가  빠르고,  비용이  비싸며  용량이  적은  메모리는?
# 입력 >>
# 오답입니다. 정답은 register  또는  레지스터 입니다.
#
#
# 140번) 컴퓨터가  한번에  처리할  수  있는  명령  크기  단위를  (         )라고  한다.
# 입력 >>
# 오답입니다. 정답은 워드  또는  word 입니다.
#
#
# 141번) 플래시  메모리는  크게  NAND  타입과  (        )  타입이  있다.
# 입력 >>
# 오답입니다. 정답은 NOR 입니다.
#
#
# 142번) OO은  컴퓨터  내부  및  외부  장치들  간에  전송  경로를  의미하며,  데이터와  명령을  전달한다.
# 입력 >>
# 오답입니다. 정답은 bus  또는  버스 입니다.
#
#
# 145번) 특정  하드웨어  장치에  포함된  소프트웨어로  소프트웨어를  읽어  실행하거나  수정하는  것도  가능한  장치를  뜻하는  소프
# 트웨어
# 입력 >>
# 오답입니다. 정답은 firware  또는  펌웨어 입니다.
#
#
# 148번) 다른  시스템에  정보를  전송하거나  조작하기  위한  경계면,  접점  또는  도구로  사용자가  기기를  쉽게  동작시키기  위한  시스
# 템
# 입력 >>
# 오답입니다. 정답은 인터페이스 입니다.
#
#
# 150번) 4차  산업혁명  시대의  원유  라고  불리우며  5V(Volume,  Variety,  Velocity,  Value,  Veracity)의  특징을  가진  것은
# 입력 >>
# 오답입니다. 정답은 빅데이터 입니다.
#
#
# 151번) 프로그래밍에  집중한  유연한  개발  방식으로  상호작용,  소프트웨어,  협력,  변화  대응에  가치를  두는  기법은
# 입력 >>
# 오답입니다. 정답은 애자일 입니다.
#
#
# 152번) 데이터에  의미를  부여해  문제를  분석하고  해결해  나가는  사람들을  말하는  직업군은
# 입력 >>
# 오답입니다. 정답은 데이터  사이언티스트 입니다.
#
#
# 153번) 사용자들의  장치와  가까운  데이터의  밑단부에서  컴퓨팅하는  기술을  일컫는  말로써  클라우드  컴퓨팅의  단점을  보완하는
# 기술은
# 입력 >>
# 오답입니다. 정답은 엣지  컴퓨팅 입니다.
#
#
# 154번) 사용자  생활환경  안에서  자연스럽게  요구사항을  인지해  필요한  서비스를  제공하며  인터페이스를  최소화  시키는  방식은
# 입력 >>
# 오답입니다. 정답은 제로UI 입니다.
#
#
# 155번) LTE  속도와  비교했을  때  LTE를  지하철이라고  하면  이  방식은  고속전철로  비유할  수  있다.  이것은  무엇인가
# 입력 >>
# 오답입니다. 정답은 5G 입니다.
#
#
# 156번) 규제를  뜻하는  regulation과  기술을  뜻하는  technology의  합성어로  금융  서비스  부문의  법규  준수와  규제를  해결하기
# 위한  기술은
# 입력 >>
# 오답입니다. 정답은 레그테크 입니다.
#
#
# 157번) 개인정보  열람  요청  권리,  정정  요청  권리,  삭제  요청  권리  등이  포함된  규정으로  유럽의회에서  개인  정보보호를  강화하
# 기  위해  만든  통합  규정은
# 입력 >>
# 오답입니다. 정답은 GDPR  (유럽일반개인정보보호법) 입니다.
#
#
# 158번) 작품을  기획하고  설명하는  큐레이터에서  파생된  서비스로  빅데이터  분석을  통해  기사,  컨텐츠  등을  개인  맞춤형으로  제
# 공하는  서비스는
# 입력 >>
# 오답입니다. 정답은 큐레이션  서비스 입니다.
#
#
# 159번) 생성적  적대  신경망을  뜻하며  상반된  목적을  가진  두  인공지능이  서로  경쟁하는  학습기법을  뜻하는  것은
# 입력 >>
# 오답입니다. 정답은 GAN 입니다.
#
#
# 160번) 디자이너들이  생각하는  방식을  다른  분야에  적용한  것으로  사용자  중심  프로세스를  통해  복잡한  문제에  대한  해결  방법
# 을  도출하는  방법은
# 입력 >>
# 오답입니다. 정답은 Design  Thinking(디자인  씽킹) 입니다.
#
#
# 161번) 사용자(비즈니스)의  의도에  따라  스스로  학습하고  적응하며  자동화할  뿐  아니라  보안위협까지도  방어해  보호할  수  있는
# 네트워크를  뜻하는  개념으로,  마치  사람과  같은  직관력을  갖고  판단해  동작하는  네트워크  라는  의미를  담은  개념은
# 입력 >>
# 오답입니다. 정답은 Intent  Based  Network 입니다.
#
#
# 162번) 네트워크  기술에서  제어와  전송  부분을  분리하는  기술로  ‘개방성’과  ‘유연성’을  핵심  기술로  실제  네트워크  기능을  모두
# SW가  통제하는  의미를  가진  네트워크는
# 입력 >>
# 오답입니다. 정답은 SDN  (Software-Defined  Network) 입니다.
#
#
# 163번) 시간과  장소에  구애받지  않고  즐길  수  있는  스낵처럼  출퇴근  시간이나  점심시간  등  짧은  시간에  간편하게  문화생활을
# 즐기는  라이프  스타일  또는  문화  트렌드를  말하는  것으로  웹툰,  웹  소설과  웹  드라마가  대표적인  이것은
# 입력 >>
# 오답입니다. 정답은 스낵  컬쳐 입니다.
#
#
# 164번) 미국  방위  산업체  ‘보스턴  다이내믹스(Boston  Dynamics)’가  만든  미래형  휴머노이드형  로봇이다.  2015년  로봇  경진대회
# ‘다르파(DARPA)  로보틱스  챌린지(DRC)’에  참가한  이후로  비약적인  발전을  거듭하여  인간과  매우  흡사한  형태로  발전한
# 로봇의  이름은
